# %% [markdown]
# <a href="https://colab.research.google.com/github/SantoshSaklani/datascience/blob/master/JsonDownload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
url = "https://plasticuproject.pythonanywhere.com/nvd-api/v1/year/2017"
df = pd.read_json(url)
for item in np.split(df, 5):
    print(item)
# Out:
# Streaming output truncated to the last 5000 lines.
# 14844  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# 14845  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# 14846  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# 14847  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# 14848  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# 14849  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# 14850  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# 14851  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# 14852  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# 14853  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# 14854  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# 14855  {'baseMetricV3': {'cvssV3': {'version': '3.0',...  2017-11-22T19:29Z
# ...

# %%
import pandas as pd
>>> url = "https://plasticuproject.pythonanywhere.com/nvd-api/v1/year/2021"
>>> df = pd.read_json(url)
>>> df.head()

df.head()
# Out:
#                                                  cve  \
# 0  {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 1  {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 2  {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 3  {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 4  {'data_type': 'CVE', 'data_format': 'MITRE', '...
#
#                                       configurations  \
# 0  {'CVE_data_version': '4.0', 'nodes': [{'operat...
# 1  {'CVE_data_version': '4.0', 'nodes': [{'operat...
# 2  {'CVE_data_version': '4.0', 'nodes': [{'operat...
# 3  {'CVE_data_version': '4.0', 'nodes': [{'operat...
# 4  {'CVE_data_version': '4.0', 'nodes': [{'operat...
#
#                                               impact      publishedDate  \
# 0  {'baseMetricV3': {'cvssV3': {'version': '3.1',...  2021-06-09T20:15Z
# 1  {'baseMetricV3': {'cvssV3': {'version': '3.1',...  2021-08-11T13:15Z
# 2  {'baseMetricV3': {'cvssV3': {'version': '3.1',...  2021-08-11T13:15Z
# ...

# %%
import pandas as pd
>>> url = "https://plasticuproject.pythonanywhere.com/nvd-api/v1/year/2020"
>>> df = pd.read_json(url)
>>> print(df)
# Out:
#                                                      cve  \
# 0      {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 1      {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 2      {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 3      {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 4      {'data_type': 'CVE', 'data_format': 'MITRE', '...
# ...                                                  ...
# 19315  {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 19316  {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 19317  {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 19318  {'data_type': 'CVE', 'data_format': 'MITRE', '...
# 19319  {'data_type': 'CVE', 'data_format': 'MITRE', '...
#
#                                           configurations  \
# 0      {'CVE_data_version': '4.0', 'nodes': [{'operat...
# 1      {'CVE_data_version': '4.0', 'nodes': [{'operat...
# 2      {'CVE_data_version': '4.0', 'nodes': [{'operat...
# ...

# %%
import pandas as pd url = "https://plasticuproject.pythonanywhere.com/nvd-api/v1/year/2020" df = pd.read_json(url)
test1 = df['impact'].str.contains('injection').value_counts()
print(test1)
# Out:
# Series([], Name: impact, dtype: int64)
